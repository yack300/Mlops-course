# %%
import mlflow

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'sqlite:////home/ubuntu/Mlops-course/02-experimenting-tracking/running-mlflow-examples/mlflow.db'

# %%
mlflow.search_experiments()
# Out:
# 2026/07/26 22:54:47 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/07/26 22:54:47 INFO mlflow.store.db.utils: Updating database tables
# [<Experiment: artifact_location='/home/ubuntu/Mlops-course/02-experimenting-tracking/running-mlflow-examples/mlruns/0', creation_time=1785106490207, effective_trace_archival_retention=None, experiment_id='0', last_update_time=1785106490207, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2026/07/26 22:55:00 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/07/26 22:55:01 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# default artifacts URI: '/home/ubuntu/Mlops-course/02-experimenting-tracking/running-mlflow-examples/mlruns/1/d7a97329e79743eba610036f8ac994e6/artifacts'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='/home/ubuntu/Mlops-course/02-experimenting-tracking/running-mlflow-examples/mlruns/1', creation_time=1785106500982, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1785106500982, lifecycle_stage='active', name='my-experiment-1', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/home/ubuntu/Mlops-course/02-experimenting-tracking/running-mlflow-examples/mlruns/0', creation_time=1785106490207, effective_trace_archival_retention=None, experiment_id='0', last_update_time=1785106490207, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
