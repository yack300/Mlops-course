# %%
import mlflow


mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'http://127.0.0.1:5000'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='/home/ubuntu/Mlops-course/02-ml-model/mlruns/2', creation_time=1784428392824, effective_trace_archival_retention=None, experiment_id='2', last_update_time=1784428392824, lifecycle_stage='active', name='my-cool-experiment', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/home/ubuntu/Mlops-course/02-ml-model/mlruns/1', creation_time=1783744047989, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1783744047989, lifecycle_stage='active', name='nyc_taxi_experiment', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1783737023715, effective_trace_archival_retention=None, experiment_id='0', last_update_time=1783737023715, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2026/07/26 23:32:36 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/07/26 23:32:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# default artifacts URI: '/home/ubuntu/Mlops-course/02-experimenting-tracking/running-mlflow-examples/artifacts_local/3/3452a76f0e36420da4ecfa14121982c7/artifacts'
# 🏃 View run sedate-rat-980 at: http://127.0.0.1:5000/#/experiments/3/runs/3452a76f0e36420da4ecfa14121982c7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='/home/ubuntu/Mlops-course/02-experimenting-tracking/running-mlflow-examples/artifacts_local/3', creation_time=1785108756192, effective_trace_archival_retention=None, experiment_id='3', last_update_time=1785108756192, lifecycle_stage='active', name='my-experiment-1', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/home/ubuntu/Mlops-course/02-ml-model/mlruns/2', creation_time=1784428392824, effective_trace_archival_retention=None, experiment_id='2', last_update_time=1784428392824, lifecycle_stage='active', name='my-cool-experiment', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/home/ubuntu/Mlops-course/02-ml-model/mlruns/1', creation_time=1783744047989, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1783744047989, lifecycle_stage='active', name='nyc_taxi_experiment', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1783737023715, effective_trace_archival_retention=None, experiment_id='0', last_update_time=1783737023715, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient("http://127.0.0.1:5000")

# %%
client.search_registered_models()
# Out:
# [<RegisteredModel: aliases={'challenger': '1', 'secondchallenger': '2'}, creation_timestamp=1784264162939, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='The NYC taxi predictor for trip duration', last_updated_timestamp=1784695431297, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1784264232614, current_stage='Archived', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description=('The model version 2 was transitioned to Production on <built-in method '
#   'timestamp of datetime.datetime object at 0x7d37bcd3e7f0>'), last_updated_timestamp=1784695431297, metrics=None, model_id=None, name='nyc-taxi-regressor', params=None, run_id='0c0a5ddfffd849cc9e6312f530ee59e0', run_link='', source='models:/m-140c56b99ee540a18a2976fdb590a898', status='READY', status_message=None, tags={'model': 'GradientBoostingRegressor'}, user_id='', version='2', workspace='default'>,
#   <ModelVersion: aliases=[], creation_timestamp=1784695429533, current_stage='Production', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description=('The model version 3 was transitioned to Production on <built-in method '
#   'timestamp of datetime.datetime object at 0x7d37bcd3efa0>'), last_updated_timestamp=1784695432001, metrics=None, model_id=None, name='nyc-taxi-regressor', params=None, run_id='f16636c84de44fd8bee32cac0bc095c2', run_link='', source='models:/m-34a9cde4dee14ef4b925d0713f9f5250', status='READY', status_message=None, tags={}, user_id='', version='3', workspace='default'>], name='nyc-taxi-regressor', tags={}, workspace='default'>,
#  <RegisteredModel: aliases={}, creation_timestamp=1784429465822, deployment_job_id='', deployment_job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', description='', last_updated_timestamp=1784695214811, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1784695214811, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description=None, last_updated_timestamp=1784695214811, metrics=None, model_id=None, name='nyc_taxi_experiment', params=None, run_id='f16636c84de44fd8bee32cac0bc095c2', run_link='', source='models:/m-34a9cde4dee14ef4b925d0713f9f5250', status='READY', status_message=None, tags={}, user_id='', version='2', workspace='default'>], name='nyc_taxi_experiment', tags={}, workspace='default'>]

# %%
experiment = client.get_experiment_by_name("my-experiment-1")
run_id = client.search_runs(experiment_ids=[experiment.experiment_id])[0].info.run_id
mlflow.register_model(
    model_uri=f"runs:/{run_id}/models",
    name='iris-classifier'
)
# Out:
# Registered model 'iris-classifier' already exists. Creating a new version of this model...
# 2026/07/26 23:34:28 WARNING mlflow.tracking._model_registry.fluent: Run with id 3452a76f0e36420da4ecfa14121982c7 has no artifacts at artifact path 'models', registering model based on models:/m-4ff54ccc57fb42baa6c36782a45f5d2d instead
# 2026/07/26 23:34:28 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: iris-classifier, version 1
# Created version '1' of model 'iris-classifier'.
# <ModelVersion: aliases=[], creation_timestamp=1785108868262, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1785108868262, metrics=None, model_id=None, name='iris-classifier', params=None, run_id='3452a76f0e36420da4ecfa14121982c7', run_link='', source='models:/m-4ff54ccc57fb42baa6c36782a45f5d2d', status='READY', status_message=None, tags={}, user_id='', version='1', workspace='default'>
